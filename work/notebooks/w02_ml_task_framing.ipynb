# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Abdul-Samad-17/FlyRank-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# My lane: *Refresh/Content Opertunity Scoring* is framed as a binary classification + ranking based problem. It classsifies weather a post is declining or not and then on the basis of each post's probability scores, it ranks them according to their declining score.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# **Target:** *is_declining_label* defined as *trend_direction = down*.
# This is a proxy label defining the current 90 days not the future outcome, since it is a begginer level approach otherwise we should use **prior 90 days -> next 30 days**

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Success Metric: **Precision@50**, since the reviewers may not be able to look up to all of the posts, so the declining rate for the top 50 will be quite enough to check the declining rate.
#
# My baseline rule scored 0.240 while random forest scored 0.7, on the clients holdout, which the model never saw during training, so that seems as a "good" score.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# one row = one post of one client with its own specifications like 90_day window etc.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)
df[["content_id", "client_id", "impressions_90d", "avg_position", "ctr", "trend_direction"]].head()
# Out:
# Shape: (30000, 44)
#              content_id          client_id  impressions_90d  avg_position  \
# 0  content_304f48230142  client_f369cb89fc             3803          10.6
# 1  content_a1fb4e703a9e  client_4e07408562            15320          20.3
# 2  content_9aa793d4d895  client_7f2253d7e2            12581          36.5
# 3  content_331d6c4de07b  client_19581e27de            11751           6.2
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140          44.0
#
#     ctr trend_direction
# 0  0.76            down
# 1  0.05            down
# 2  0.09            down
# 3  0.49          stable
# 4  0.13            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A single if statement checks only a single pattern while in practical cases the output depends on a lot of patterns and inputs, and ML models not just calculates those limited inputs, instead they lerans those patterns and generalize the whole data, so they also perform well on unseen data.
# That's why ML beats a fixed rule (24 -> 74).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
